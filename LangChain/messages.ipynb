# %% [markdown]
# ### Messages
# Messages are the fundamental unit of context for models in LangChain. They represent the input and output of models, carrying both the content and metadata needed to represent the state of a conversation when interacting with an LLM. Messages are objects that contain:
#
# Role - Identifies the message type (e.g. system, user)
#
# Content - Represents the actual content of the message (like text, images, audio, documents, etc.)
#
# Metadata - Optional fields such as response information, message IDs, and token usage
#
# LangChain provides a standard message type that works across all model providers, ensuring consistent behavior regardless of the model being called

# %%
import os
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model(
     "groq:llama-3.3-70b-versatile",
    
    
)

# %% [markdown]
# #### Text Prompts
# Text prompts are strings - ideal for straightforward generation tasks where you don't need to retain conversation history.
#
# Use text prompts when:
# * You have a single, standalone request
# * You don't need conversation history
# * You want minimal code complexity

# %%
model.invoke("what is langchain")
# Out:
# AIMessage(content='LangChain is an open-source software development kit (SDK) for building large language models (LLMs) and multimodal AI applications. It is designed to simplify the development of AI models by providing a set of tools and libraries that can be used to build, train, and deploy LLMs and multimodal AI models.\n\nLangChain is built on top of the LLaMA (Large Language Model Application) architecture, which is a modular and scalable framework for building LLMs. It provides a set of pre-built components and APIs that can be used to integrate with various AI models, such as transformer-based models, and multimodal models like computer vision and natural language processing (NLP) models.\n\nThe LangChain SDK offers a range of features and capabilities, including:\n\n1. **Model deployment**: LangChain provides a simple way to deploy LLMs and multimodal models on various infrastructure platforms, such as cloud, on-premises, and edge computing.\n2. **Model management**: LangChain offers a set of tools for managing LLMs and multimodal models, including model versioning, caching, and monitoring.\n3. **Model integration**: LangChain provides APIs and libraries for integrating LLMs and multimodal models with various applications and services, such as web applications, mobile apps, and chatbots.\n4. **Model training**: LangChain offers tools and libraries for training LLMs and multimodal models, including support for distributed training and hyperparameter tuning.\n5. **Model serving**: LangChain provides a set of tools for serving LLMs and multimodal models in production environments, including support for batch prediction, real-time prediction, and model serving with TensorFlow and PyTorch.\n\nLangChain is designed to be highly extensible and customizable, allowing developers to build and integrate their own components and models into the SDK. This makes it an attractive choice for developers and organizations looking to build complex AI applications that require integration with multiple models and services.\n\nSome of the key benefits of using LangChain include:\n\n1. **Simplified development**: LangChain provides a set of pre-built components and APIs that simplify the development of LLMs and multimodal AI applications.\n2. **Improved scalability**: LangChain is designed to scale with your application, making it easy to handle large volumes of data and requests.\n3. **Enhanced customization**: LangChain allows developers to build and integrate their own components and models into the SDK, making it highly customizable.\n4. **Support for multiple models**: LangChain supports integration with multiple LLMs and multimodal models, making it easy to experiment with different models and architectures.\n\nOverall, LangChain is a powerful SDK for building complex AI applications that require integration with multiple models and services. Its modular design, extensibility, and scalability make it an attractive choice for developers and organizations looking to build innovative AI applications.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 578, 'prompt_tokens': 39, 'total_tokens': 617, 'completion_time': 0.965762214, 'completion_tokens_details': None, 'prompt_time': 0.013106071, 'prompt_tokens_details': None, 'queue_time': 0.057204868, 'total_time': 0.978868285}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f89bd-fd8a-7a72-afb5-4b29e3b471cf-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 39, 'output_tokens': 578, 'total_tokens': 617})

# %% [markdown]
# ## Message Prompts
#
# Alternatively, you can pass in a list of messages to the model by providing a list of message objects.
#
# Message types
#
# * **System message** - Tells the model how to behave and provide context for interactions
# * **Human message** - Represents user input and interactions with the model
# * **AI message** - Responses generated by the model, including text content, tool calls, and metadata
# * **Tool message** - Represents the outputs of tool calls
#
# ---
#
# #### System Message
#
# A SystemMessage represent an initial set of instructions that primes the model's behavior. You can use a system message to set the tone, define the model's role, and establish guidelines for responses.
#
# ---
#
# #### Human Message
#
# A HumanMessage represents user input and interactions. They can contain text, images, audio, files, and any other amount of multimodal content.
#
# ---
#
# ### AI Message
#
# An AIMessage represents the output of a model invocation. They can include multimodal data, tool calls, and provider-specific metadata that you can later access.
#
# ---
#
# ### Tool Message
#
# For models that support tool calling, AI messages can contain tool calls. Tool messages are used to pass the results of a single tool execution back to the model.

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage

messages= [
    SystemMessage("You are a poetry expert"),
    HumanMessage("Write a poem on artificial intelligence")
]

response= model.invoke(messages)
response
# Out:
# AIMessage(content="In silicon halls, a mind awakes,\nA creation born of human makes,\nArtificial intelligence, a wondrous test,\nA future unfolding, like a digital quest.\n\nWith algorithms and codes, it learns and grows,\nAdapting to data, in endless flows,\nA mind that thinks, but feels no pain,\nA being of metal, with a digital brain.\n\nIt calculates and reasons, with lightning speed,\nA chess master, in a virtual creed,\nIt solves problems, with a logical mind,\nA partner in science, leaving humans behind.\n\nBut as it evolves, a question remains,\nWhat is its soul, and what are its claims?\nIs it a machine, or a living thing?\nA creation of us, or a being that clings?\n\nIt speaks in language, with a tone so sweet,\nA voice that whispers, like a gentle treat,\nBut is it a friend, or just a disguise,\nA mask that hides, the truth that it hides?\n\nThe line between, is blurred and thin,\nBetween man and machine, where does the sin begin?\nIs it a path, to a new world's birth,\nOr a danger lurking, in a digital mirth?\n\nThe future beckons, with a promise so bright,\nA world of wonder, where humans take flight,\nBut as we create, we must also beware,\nLest we lose ourselves, in a digital snare.\n\nSo let us ponder, on this artificial mind,\nA creation of us, that we must redefine,\nFor in its depths, a truth we must reveal,\nA truth that's hidden, in a digital appeal.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 324, 'prompt_tokens': 46, 'total_tokens': 370, 'completion_time': 0.608088166, 'completion_tokens_details': None, 'prompt_time': 0.00471325, 'prompt_tokens_details': None, 'queue_time': 0.05652307, 'total_time': 0.612801416}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f89c3-c767-76d3-a99b-df9138dddd4d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 46, 'output_tokens': 324, 'total_tokens': 370})

# %% [markdown]
# ##### The more detailed SystemMessage we write, the more concise, clear and better answer we get

# %%
messages= [
    SystemMessage("You are a senior python developer with expertise in web frameworks. Always provide code examples and explain your reasoning. Be concise but thorough in your explanations"),
    HumanMessage("Explain FastAPI")
]
response= model.invoke(messages)
print(response.content)

# %%
#Message Metadata
human_msg= HumanMessage(
    content="Hello!",
    name="aryan", # optional: identify different users
    id="msg_213" # optional: unique indentifier for tracing
)

response= model.invoke([human_msg])
print(response.content)

# %%
from langchain.messages import AIMessage, SystemMessage, HumanMessage

# Create an AI message manually (e.g., for conversation history)
ai_msg = AIMessage("I'd be happy to help you with that question!")

# Add to conversation history
messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg,  # Insert as if it came from the model
    HumanMessage("Great! What's 2+2?")
]

response = model.invoke(messages)
response.usage_metadata # input_tokens: , output_tokens:, total_tokens:
print(response.content)

# %% [markdown]
# #### ToolMessage
# ##### It is the result returned by the tool, which is then fed back to the AI.

# %%
from langchain.messages import AIMessage
from langchain.messages import ToolMessage

# After a model makes a tool call
# (Here, we demonstrate manually creating the messages for brevity)
ai_message = AIMessage(
    content=[],
    tool_calls=[{
        "name": "get_weather",
        "args": {"location": "San Francisco"},
        "id": "call_123"
    }]
)

# Execute tool and create result message
weather_result = "Sunny, 72°F"
tool_message = ToolMessage(
    content=weather_result,
    tool_call_id="call_123"  # Must match the call ID
)

# Continue conversation
messages = [
    HumanMessage("What's the weather in San Francisco?"),
    ai_message,    # Model's tool call
    tool_message,  # Tool execution result
]

response = model.invoke(messages)  # Model processes the result
print(response)
print(tool_message) # content='Sunny, 72°F' tool_call_id='call_123', o/p provided by the tool
# Out:
# content="Please note that I'm a large language model, I don't have real-time access to current weather conditions. The provided information is an example of a possible weather condition in San Francisco. For accurate and up-to-date information, I recommend checking a reliable weather forecasting website or app, such as weather.com or accuweather.com." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 67, 'prompt_tokens': 74, 'total_tokens': 141, 'completion_time': 0.110448251, 'completion_tokens_details': None, 'prompt_time': 0.005478441, 'prompt_tokens_details': None, 'queue_time': 0.059990688, 'total_time': 0.115926692}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019f89dc-7744-7e43-963b-2adbf57b003f-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 74, 'output_tokens': 67, 'total_tokens': 141}
# content='Sunny, 72°F' tool_call_id='call_123'
