# %% [markdown]
# ### We are building a very simple MCP Server which is for doing math operations
# thereofe the tools are- add(), subtract() etc..

# %%
from mcp.server.fastmcp import fastMCP

mcp = fastMCP("Math") # naming the MCP Server as "Math"
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from mcp.server.fastmcp import fastMCP
#
# ImportError: cannot import name 'fastMCP' from 'mcp.server.fastmcp' (d:\Agentic_AI\LangChain\.venv\Lib\site-packages\mcp\server\fastmcp\__init__.py)
